# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.drop(["class","who","adult_male","deck","embark_town","alive"],axis=1, inplace=True)

# %%
X = df.drop(columns=["survived"])
y = df["survived"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# imputation Transformer

trf1 = ColumnTransformer([
    ("impute_age",SimpleImputer(),[2]),
    ("impute_embarked",SimpleImputer(strategy="most_frequent"),[6])
], remainder="passthrough")

# %%
# one hot encoding

trf2 = ColumnTransformer([
     ("ohe_sex_embarked_alone",OneHotEncoder(handle_unknown="ignore"),[1,6,7])
], remainder="passthrough")

# %%
trf3 = ColumnTransformer([
    ("scale",StandardScaler())
])

# %%
trf4 = Decis

# %%
pd.DataFrame(X_train_embarked).isnull().sum()
# Out:
# 0    0
# dtype: int64

# %%
X_train
# Out:
#      pclass     sex   age  sibsp  parch      fare embarked  alone
# 331       1    male  45.5      0      0   28.5000        S   True
# 733       2    male  23.0      0      0   13.0000        S   True
# 382       3    male  32.0      0      0    7.9250        S   True
# 704       3    male  26.0      1      0    7.8542        S  False
# 813       3  female   6.0      4      2   31.2750        S  False
# ..      ...     ...   ...    ...    ...       ...      ...    ...
# 106       3  female  21.0      0      0    7.6500        S   True
# 270       1    male   NaN      0      0   31.0000        S   True
# 860       3    male  41.0      2      0   14.1083        S  False
# 435       1  female  14.0      1      2  120.0000        S  False
# 102       1    male  21.0      0      1   77.2875        S  False
#
# [712 rows x 8 columns]
